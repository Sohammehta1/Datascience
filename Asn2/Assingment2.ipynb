# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch
# 0    female        group B           bachelor's degree      standard  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course math score  reading score  writing score
# 0                      none         72           72.0           74.0
# ...

# %%
df['gender'] = df.gender.astype('category')
df['gender'] = df['gender'].cat.codes

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch
# 0         0        group B           bachelor's degree      standard  \
# 1         0        group C                some college      standard
# 2         0        group B             master's degree      standard
# 3         1        group A          associate's degree  free/reduced
# 4         1        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995       0        group E             master's degree      standard
# 996       1        group C                 high school  free/reduced
# 997       0        group C                 high school  free/reduced
# 998       0        group D                some college      standard
# 999       0        group D                some college  free/reduced
#
#     test preparation course math score  reading score  writing score
# 0                      none         72           72.0           74.0
# ...

# %%
df['race/ethnicity'] = df['race/ethnicity'].astype('category')
df['race/ethnicity'] = df['race/ethnicity'].cat.codes

# %%
df
# Out:
#      gender  race/ethnicity parental level of education         lunch
# 0         0               1           bachelor's degree      standard  \
# 1         0               2                some college      standard
# 2         0               1             master's degree      standard
# 3         1               0          associate's degree  free/reduced
# 4         1               2                some college      standard
# ..      ...             ...                         ...           ...
# 995       0               4             master's degree      standard
# 996       1               2                 high school  free/reduced
# 997       0               2                 high school  free/reduced
# 998       0               3                some college      standard
# 999       0               3                some college  free/reduced
#
#     test preparation course math score  reading score  writing score
# ...

# %%
df['parental level of education'] = df['parental level of education'].astype('category')
df['parental level of education'] = df['parental level of education'].cat.codes

# %%
df
# Out:
#      gender  race/ethnicity  parental level of education         lunch
# 0         0               1                            1      standard  \
# 1         0               2                            4      standard
# 2         0               1                            3      standard
# 3         1               0                            0  free/reduced
# 4         1               2                            4      standard
# ..      ...             ...                          ...           ...
# 995       0               4                            3      standard
# 996       1               2                            2  free/reduced
# 997       0               2                            2  free/reduced
# 998       0               3                            4      standard
# 999       0               3                            4  free/reduced
#
#     test preparation course math score  reading score  writing score
# ...

# %%
df['lunch'] = df['lunch'].astype('category')
df['lunch'] = df['lunch'].cat.codes
df
# Out:
#      gender  race/ethnicity  parental level of education  lunch
# 0         0               1                            1      1  \
# 1         0               2                            4      1
# 2         0               1                            3      1
# 3         1               0                            0      0
# 4         1               2                            4      1
# ..      ...             ...                          ...    ...
# 995       0               4                            3      1
# 996       1               2                            2      0
# 997       0               2                            2      0
# 998       0               3                            4      1
# 999       0               3                            4      0
#
#     test preparation course math score  reading score  writing score
# 0                      none         72           72.0           74.0
# ...

# %%
df['test preparation course'] = df['test preparation course'].astype('category')
df['test preparation course'] = df['test preparation course'].cat.codes
df
# Out:
#      gender  race/ethnicity  parental level of education  lunch
# 0         0               1                            1      1  \
# 1         0               2                            4      1
# 2         0               1                            3      1
# 3         1               0                            0      0
# 4         1               2                            4      1
# ..      ...             ...                          ...    ...
# 995       0               4                            3      1
# 996       1               2                            2      0
# 997       0               2                            2      0
# 998       0               3                            4      1
# 999       0               3                            4      0
#
#      test preparation course math score  reading score  writing score
# 0                          1         72           72.0           74.0
# ...

# %%
df=df.fillna(0.0)

# %%
df['math score'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#      gender  race/ethnicity  parental level of education  lunch
# 0         0               1                            1      1  \
# 1         0               2                            4      1
# 2         0               1                            3      1
# 3         1               0                            0      0
# 4         1               2                            4      1
# ..      ...             ...                          ...    ...
# 995       0               4                            3      1
# 996       1               2                            2      0
# 997       0               2                            2      0
# 998       0               3                            4      1
# 999       0               3                            4      0
#
#      test preparation course math score  reading score  writing score
# 0                          1         72           72.0           74.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.describe()
# Out:
#             gender  race/ethnicity  parental level of education        lunch
# count  1000.000000     1000.000000                  1000.000000  1000.000000  \
# mean      0.482000        2.174000                     2.486000     0.645000
# std       0.499926        1.157179                     1.829522     0.478753
# min       0.000000        0.000000                     0.000000     0.000000
# 25%       0.000000        1.000000                     1.000000     0.000000
# 50%       0.000000        2.000000                     2.000000     1.000000
# 75%       1.000000        3.000000                     4.000000     1.000000
# max       1.000000        4.000000                     5.000000     1.000000
#
#        test preparation course  reading score  writing score
# count              1000.000000    1000.000000    1000.000000
# mean                  0.642000      67.600000      68.862000
# std                   0.479652      17.366393      30.153776
# ...

# %%
df['math score'].replace('?', np.nan, inplace=True)
df['math score'] = df['math score'].astype(float)
math_score  = df['math score'].clip(0.0,100.0)
sns.histplot(math_score,bins=25,kde=True)
plt.axvline(math_score.mean(), color = 'k', linestyle='dashed', linewidth=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 4
#       2 df['math score'] = df['math score'].astype(float)
#       3 math_score  = df['math score'].clip(0.0,100.0)
# ----> 4 sns.histplot(math_score,bins=25,kde=True)
#       5 plt.axvline(math_score.mean(), color = 'k', linestyle='dashed', linewidth=1)
#       6 plt.show()
#
# File /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:1432, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1421 estimate_kws = dict(
#    1422     stat=stat,
#    1423     bins=bins,
#    (...)
#    1427     cumulative=cumulative,
#    1428 )
#    1430 if p.univariate:
# ...

# %%
df['reading score'].replace('?', np.nan, inplace=True)
df['reading score'] = df['reading score'].astype(float)

# %%
fig,axes = plt.subplots(1,2,figsize=(10,4))

math_score  = df['math score'].clip(0.0,100.0)

q1 = np.percentile(math_score,25)
q3 = np.percentile(math_score,75)
iqr = q3-q1

clipped_math_score= math_score.clip(q1, q3)
print(math_score.describe(), " ", clipped_math_score.describe())
# sns.histplot(math_score,bins=25,kde=True, ax=axes[0])
# axes[0].axvline(math_score.mean(), color = 'k',linestyle='dashed', linewidth=1)

# sns.histplot(clipped_math_score,bins=25,kde=True, ax =axes[1])
# plt.axvline(clipped_math_score.mean(), color = 'k',linestyle='dashed', linewidth=1)
# Out:
# count    965.000000
# mean      65.586528
# std       16.446822
# min        0.000000
# 25%       56.000000
# 50%       66.000000
# 75%       77.000000
# max      100.000000
# Name: math score, dtype: float64   count    965.000000
# mean      65.586528
# std       16.446822
# min        0.000000
# 25%       56.000000
# 50%       66.000000
# 75%       77.000000
# max      100.000000
# Name: math score, dtype: float64

# %%
fig,axes = plt.subplots(1,2,figsize=(10,4))
reading_score  = df['reading score'].clip(0.0,100.0)


q1 = np.percentile(reading_score,25)
q3 = np.percentile(reading_score,75)
iqr = q3-q1
clipped_reading_score= reading_score.clip(q1-1.5*iqr, q3+1.5*iqr)
print(reading_score.describe(), " ", clipped_reading_score.describe())
sns.histplot(reading_score,bins=25,kde=True, ax=axes[0])
axes[0].axvline(reading_score.mean(), color = 'k',linestyle='dashed', linewidth=1)
sns.histplot(clipped_reading_score,bins=25,kde=True, ax =axes[1])
plt.axvline(clipped_reading_score.mean(), color = 'k',linestyle='dashed', linewidth=1)
plt.show()

# %%
fig,axes = plt.sq1 = np.percentile(writing_score,25)
q3 = np.percentile(writing_score,75)
iqr = q3-q1
clipped_writing_score= writing_score.clip(q1-1.5*iqr, q3+1.5*iqr)
print(writing_score.describe(), " ", clipped_writing_score.describe())
sns.histplot(writing_score,bins=25,kde=True, ax=axes[0])
axes[0].axvline(writing_score.mean(), color = 'k',linestyle='dashed', linewidth=1)
sns.histplot(clipped_writing_score,bins=25,kde=True, ax =axes[1])
plt.axvline(clipped_writing_score.mean(), color = 'k',linestyle='dashed', linewidth=1)
plt.show()ubplots(1,2,figsize=(10,4))
writing_score  = df['writing score'].clip(0.0,100.0)


q1 = np.percentile(writing_score,25)
q3 = np.percentile(writing_score,75)
iqr = q3-q1
clipped_writing_score= writing_score.clip(q1-1.5*iqr, q3+1.5*iqr)
print(writing_score.describe(), " ", clipped_writing_score.describe())
sns.histplot(writing_score,bins=25,kde=True, ax=axes[0])
axes[0].axvline(writing_score.mean(), color = 'k',linestyle='dashed', linewidth=1)
sns.histplot(clipped_writing_score,bins=25,kde=True, ax =axes[1])
plt.axvline(clipped_writing_score.mean(), color = 'k',linestyle='dashed', linewidth=1)
plt.show()

# %%
plt.scatter(math_score, reading_score,color='blue', label='math_score')
plt.scatter(reading_score,writing_score, color='red', label='reading_score')
plt.scatter(writing_score, math_score,color='yellow', label='math_score')
plt.legend()

# %%
plt.scatter(math_score, writing_score,color='blue', label='math_score')
plt.scatter(writing_score,math_score, color='red', label='writing_score')
plt.legend()

# %%
plt.scatter(writing_score, reading_score,color='blue', label='math_score')
plt.scatter(reading_score,writing_score, color='red', label='reading_score')
plt.legend()iqr = q3-q1
