# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Social_Network_Ads.xls')

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df['Gender'] =  df.Gender.astype('category')

# %%
df['Gender'] = df['Gender'].cat.codes

# %%
print(df)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510       1   19            19000          0
# 1    15810944       1   35            20000          0
# 2    15668575       0   26            43000          0
# 3    15603246       0   27            57000          0
# 4    15804002       1   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863       0   46            41000          1
# 396  15706071       1   51            23000          1
# 397  15654296       0   50            20000          1
# 398  15755018       1   36            33000          0
# 399  15594041       0   49            36000          1
#
# [400 rows x 5 columns]

# %%
X = df.drop(columns=['Purchased','User ID','Gender'])
Y = df['Purchased']

# %%
print(X)
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
fig,axes = plt.subplots(1,3,figsize = (14,4))
sns.countplot(data = df, x = 'Purchased',hue='Gender',ax = axes[0])
sns.scatterplot(data =df,x = 'Age',y='Purchased',hue='Age',ax =axes[1])
sns.scatterplot(data =df,x = 'EstimatedSalary',y='Purchased',ax =axes[2])

# %%
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# ## From the above we can observe that, Purchased has good correlation with Age and slightly less with Estimated salary

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


x_train,x_test, y_train,y_test = train_test_split(X,Y, train_size=0.8, random_state=0)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_pred,y_test)
print(acc)
# Out:
# 0.925

# %%
from sklearn.metrics import precision_score, confusion_matrix,recall_score,f1_score

cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# %%
print(cm)
print(precision)
print(recall)
print(f1)
# Out:
# [[57  1]
#  [ 5 17]]
# 0.9444444444444444
# 0.7727272727272727
# 0.85

# %%
sns.lmplot(x='Age', y='Purchased', data=df, logistic=True, ci=None)

# %%
sns.lmplot(x='EstimatedSalary', y='Purchased', data=df, logistic=True, ci=None)

# %% [markdown]
# ## Below is the logistic function only using Age salary as a feature

# %%
X2 = df.drop(columns=['Purchased','User ID','Gender'])

# %%
x_train,x_test, y_train,y_test = train_test_split(X2,Y, train_size=0.8, random_state=0)

# %%
model2 = LogisticRegression()

# %%
model2.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred2 = model2.predict(x_test)

# %%
acc2 = accuracy_score(y_pred2,y_test)
print(acc2)
# Out:
# 0.725

# %%
cm2 = confusion_matrix(y_test, y_pred)
precision2 = precision_score(y_test, y_pred)
recall2 = recall_score(y_test, y_pred)
f1_2 = f1_score(y_test, y_pred)

# %%
print(cm2)
print(precision2)
print(recall2)
print(f1_2)
# Out:
# [[57  1]
#  [ 5 17]]
# 0.9444444444444444
# 0.7727272727272727
# 0.85

# %%
tp,tn,fp,fn = cm2[1][1],cm2[0,0],cm2[0][1], cm2[1][0]
manual_precision = tp/(tp+fp)
print(manual_precision)
manual_recall = tp/(tp+fn)
print(manual_recall)
manual_f1 = 2*(manual_precision*manual_recall)/(manual_precision+manual_recall)
print(manual_f1)
# Out:
# 0.9444444444444444
# 0.7727272727272727
# 0.85
